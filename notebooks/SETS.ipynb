# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## set = MUTABLE hence NOT hashable --> cannot be used as dictionary key
#
# ### Elements of a set MUST be hashable
#
# ### Also we cannot have  a set of sets.

# %% [markdown]
# ### frozenset is hashable. We can have a set of frozensets
